# %% [markdown]
# ## 上海数据集

# %%
import matplotlib.pyplot as plt

# 数据
methods = ['MLR', 'RR', 'LR', 'DT', 'RF', 'ChatGPT(5-shot)']
mse = [4.83e+7, 4.00e+7, 3.98e+7, 3.88e+7, 3.71e+7, 6.09e+7]
mae = [3.42e+3, 3.40e+3, 3.36e+3, 3.29e+3, 3.06e+3, 3.71e+3]

fig, ax1 = plt.subplots()

# 绘制 MSE 使用左侧的 y 轴
ax1.set_xlabel('Methods')
ax1.set_ylabel('MSE')
ax1.plot(methods, mse, marker='o', label='MSE', color='tab:blue')
ax1.tick_params(axis='y')
ax1.set_ylim([min(mse) * 0.9, max(mse) * 1.1])  # 设置 y 轴范围

# 创建一个共享 x 轴的第二个 y 轴用于 MAE
ax2 = ax1.twinx()  
ax2.set_ylabel('MAE')
ax2.plot(methods, mae, marker='x', label='MAE', color='tab:green')
ax2.tick_params(axis='y')
ax2.set_ylim([min(mae) * 0.9, max(mae) * 1.1])  # 设置 y 轴范围

# 合并图例
fig.tight_layout()
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='best')

plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
methods = ['ChatGPT(0-shot)', 'ChatGPT(1-shot)', 'ChatGPT(5-shot)', 'ChatGPT(10-shot)']
mse = [9.47e+7, 1.06e+8, 6.09e+7, 7.38e+7]
mae = [4.45e+3, 4.67e+3, 3.71e+3, 3.85e+3]

fig, ax1 = plt.subplots()

# 绘制 MSE 使用左侧的 y 轴
ax1.set_xlabel('Number of few-shot examples in ChatGPT')
ax1.set_ylabel('MSE')
ax1.plot(methods, mse, marker='o', label='MSE', color='tab:blue')
ax1.tick_params(axis='y')
ax1.set_ylim([min(mse) * 0.9, max(mse) * 1.1])  # 设置 y 轴范围

# 创建一个共享 x 轴的第二个 y 轴用于 MAE
ax2 = ax1.twinx()  
ax2.set_ylabel('MAE')
ax2.plot(methods, mae, marker='x', label='MAE', color='tab:green')
ax2.tick_params(axis='y')
ax2.set_ylim([min(mae) * 0.9, max(mae) * 1.1])  # 设置 y 轴范围

# 合并图例
fig.tight_layout()
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='best')

plt.show()
